# %%
import matplotlib
matplotlib.use('Agg')

# %%
print('hello world 0')
# Out:
# hello world 0

# %%
9 - 50
# Out:
# -41

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.rand(100, 5))
df
# Out:
#            0         1         2         3         4
# 0   0.990269  0.522996  0.870126  0.513245  0.716824
# 1   0.655167  0.231578  0.158042  0.147027  0.456575
# 2   0.748308  0.652419  0.362912  0.768882  0.292796
# 3   0.077518  0.303651  0.514293  0.272602  0.016502
# 4   0.911214  0.290731  0.833118  0.134273  0.880035
# ..       ...       ...       ...       ...       ...
# 95  0.779187  0.341432  0.996364  0.059675  0.249922
# 96  0.243281  0.752159  0.388151  0.159833  0.998571
# 97  0.188658  0.424025  0.408233  0.784539  0.645742
# 98  0.385425  0.045840  0.792391  0.255023  0.442996
# 99  0.539362  0.189403  0.557552  0.637602  0.872307
#
# [100 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(df.corr())
plt.show()

# %%
print('hello world 1')
# Out:
# hello world 1

# %%
69 - 74
# Out:
# -5

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.rand(100, 5))
df
# Out:
#            0         1         2         3         4
# 0   0.628713  0.972620  0.661601  0.441804  0.987927
# 1   0.652227  0.506897  0.345543  0.042295  0.608151
# 2   0.118131  0.865341  0.930405  0.443591  0.083507
# 3   0.751939  0.521458  0.799000  0.138200  0.133484
# 4   0.630627  0.827789  0.785314  0.142587  0.341520
# ..       ...       ...       ...       ...       ...
# 95  0.665783  0.303343  0.596601  0.466070  0.763807
# 96  0.852575  0.789036  0.068337  0.542564  0.402411
# 97  0.035357  0.537560  0.318477  0.597735  0.147595
# 98  0.306068  0.974920  0.828585  0.913835  0.874367
# 99  0.322874  0.424456  0.492328  0.593966  0.379734
#
# [100 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(df.corr())
plt.show()

# %%
print('hello world 2')
# Out:
# hello world 2

# %%
72 - 1
# Out:
# 71

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.rand(100, 5))
df
# Out:
#            0         1         2         3         4
# 0   0.648829  0.345043  0.807071  0.555321  0.392521
# 1   0.103103  0.613836  0.993597  0.244765  0.261724
# 2   0.463082  0.637188  0.670418  0.009746  0.054369
# 3   0.711363  0.222316  0.427867  0.547462  0.166371
# 4   0.545690  0.760275  0.456053  0.192645  0.115702
# ..       ...       ...       ...       ...       ...
# 95  0.488847  0.143044  0.446276  0.573977  0.495999
# 96  0.470885  0.009811  0.095834  0.478117  0.308448
# 97  0.925389  0.241640  0.178271  0.968410  0.012949
# 98  0.642701  0.410127  0.569903  0.973269  0.126574
# 99  0.069249  0.681079  0.941308  0.339130  0.774547
#
# [100 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(df.corr())
plt.show()

# %%
print('hello world 3')
# Out:
# hello world 3

# %%
33 - 39
# Out:
# -6

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.rand(100, 5))
df
# Out:
#            0         1         2         3         4
# 0   0.946377  0.587733  0.658219  0.740946  0.162770
# 1   0.573336  0.885325  0.436055  0.771831  0.416692
# 2   0.207203  0.146766  0.541409  0.230718  0.177778
# 3   0.389745  0.341516  0.880559  0.779113  0.028930
# 4   0.545619  0.946827  0.047173  0.120790  0.064717
# ..       ...       ...       ...       ...       ...
# 95  0.900137  0.504170  0.987753  0.386307  0.667035
# 96  0.709345  0.141248  0.514380  0.857192  0.330075
# 97  0.792924  0.086987  0.741860  0.835210  0.554862
# 98  0.881489  0.662907  0.726515  0.399180  0.968896
# 99  0.611012  0.800044  0.383259  0.678149  0.836650
#
# [100 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(df.corr())
plt.show()

# %%
print('hello world 4')
# Out:
# hello world 4

# %%
0 - 79
# Out:
# -79

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.rand(100, 5))
df
# Out:
#            0         1         2         3         4
# 0   0.526113  0.132323  0.309775  0.879548  0.649613
# 1   0.080329  0.815296  0.936882  0.257711  0.371187
# 2   0.948491  0.940548  0.658306  0.713683  0.622717
# 3   0.838638  0.331677  0.704595  0.567505  0.711943
# 4   0.197517  0.961660  0.478366  0.658238  0.771585
# ..       ...       ...       ...       ...       ...
# 95  0.068719  0.194357  0.084745  0.708730  0.904271
# 96  0.697915  0.956432  0.646799  0.586810  0.598181
# 97  0.107129  0.377272  0.311283  0.670667  0.959610
# 98  0.285123  0.235734  0.755238  0.333596  0.429832
# 99  0.924235  0.729471  0.367307  0.552042  0.731606
#
# [100 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(df.corr())
plt.show()

# %%
print('hello world 5')
# Out:
# hello world 5

# %%
100 - 30
# Out:
# 70

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.rand(100, 5))
df
# Out:
#            0         1         2         3         4
# 0   0.354227  0.844554  0.981409  0.397341  0.586732
# 1   0.766534  0.974948  0.441671  0.181187  0.697910
# 2   0.801222  0.239088  0.942455  0.465124  0.148256
# 3   0.898797  0.615806  0.115845  0.524379  0.770059
# 4   0.886264  0.740236  0.308280  0.355424  0.249432
# ..       ...       ...       ...       ...       ...
# 95  0.378805  0.617216  0.343753  0.238138  0.394370
# 96  0.640444  0.454993  0.267302  0.648046  0.804513
# 97  0.829891  0.065794  0.466726  0.999801  0.592015
# 98  0.334321  0.174126  0.274388  0.675937  0.401157
# 99  0.887096  0.057293  0.501268  0.912106  0.897979
#
# [100 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(df.corr())
plt.show()

# %%
print('hello world 6')
# Out:
# hello world 6

# %%
16 - 14
# Out:
# 2

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.rand(100, 5))
df
# Out:
#            0         1         2         3         4
# 0   0.189923  0.951929  0.938261  0.055933  0.962066
# 1   0.694803  0.604864  0.844938  0.403964  0.728745
# 2   0.471360  0.138207  0.271516  0.530698  0.022033
# 3   0.088711  0.242058  0.818045  0.595470  0.992464
# 4   0.268302  0.343521  0.990519  0.029863  0.319630
# ..       ...       ...       ...       ...       ...
# 95  0.214446  0.904665  0.426137  0.628389  0.568608
# 96  0.140030  0.192837  0.984563  0.540204  0.309787
# 97  0.023538  0.130709  0.700687  0.829441  0.841335
# 98  0.519348  0.664186  0.966764  0.953576  0.652569
# 99  0.695067  0.157494  0.125208  0.353265  0.316873
#
# [100 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(df.corr())
plt.show()

# %%
print('hello world 7')
# Out:
# hello world 7

# %%
97 - 61
# Out:
# 36

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.rand(100, 5))
df
# Out:
#            0         1         2         3         4
# 0   0.410237  0.796489  0.588836  0.841823  0.789257
# 1   0.509067  0.446434  0.071015  0.701589  0.428379
# 2   0.656840  0.084567  0.459157  0.281300  0.515892
# 3   0.042617  0.090484  0.469419  0.723704  0.966589
# 4   0.647453  0.903659  0.950271  0.500474  0.037669
# ..       ...       ...       ...       ...       ...
# 95  0.489573  0.836341  0.235776  0.540226  0.581448
# 96  0.492756  0.755783  0.107480  0.793857  0.517237
# 97  0.975629  0.808611  0.406895  0.937636  0.525265
# 98  0.840502  0.034890  0.009970  0.982375  0.474480
# 99  0.880058  0.888112  0.425702  0.400527  0.062287
#
# [100 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(df.corr())
plt.show()

# %%
print('hello world 8')
# Out:
# hello world 8

# %%
19 - 10
# Out:
# 9

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.rand(100, 5))
df
# Out:
#            0         1         2         3         4
# 0   0.037718  0.608155  0.761025  0.020423  0.429798
# 1   0.106124  0.530994  0.492031  0.941995  0.054375
# 2   0.777628  0.749504  0.138862  0.875559  0.494719
# 3   0.577278  0.260675  0.952766  0.366142  0.816850
# 4   0.443626  0.316477  0.014490  0.407625  0.874053
# ..       ...       ...       ...       ...       ...
# 95  0.460669  0.576079  0.924408  0.711783  0.074202
# 96  0.662436  0.016319  0.988788  0.580960  0.143297
# 97  0.273429  0.656762  0.282407  0.058916  0.071813
# 98  0.682693  0.425606  0.544496  0.964476  0.725716
# 99  0.003255  0.041739  0.202217  0.208719  0.667138
#
# [100 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(df.corr())
plt.show()

# %%
print('hello world 9')
# Out:
# hello world 9

# %%
77 - 9
# Out:
# 68

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.rand(100, 5))
df
# Out:
#            0         1         2         3         4
# 0   0.627360  0.182257  0.403312  0.251486  0.935089
# 1   0.143787  0.427331  0.634746  0.231099  0.144048
# 2   0.787129  0.056843  0.468348  0.834650  0.848900
# 3   0.420489  0.008088  0.792360  0.154892  0.295228
# 4   0.367960  0.344282  0.250651  0.169041  0.065208
# ..       ...       ...       ...       ...       ...
# 95  0.287853  0.125591  0.842248  0.081067  0.482238
# 96  0.992059  0.127672  0.083318  0.847564  0.123369
# 97  0.923849  0.063398  0.393427  0.963033  0.642723
# 98  0.157306  0.445600  0.359497  0.326815  0.501349
# 99  0.510098  0.595867  0.758637  0.584435  0.295541
#
# [100 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(df.corr())
plt.show()

# %%
print('hello world 10')
# Out:
# hello world 10

# %%
99 - 91
# Out:
# 8

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.rand(100, 5))
df
# Out:
#            0         1         2         3         4
# 0   0.216239  0.874723  0.144377  0.163447  0.517156
# 1   0.146809  0.406892  0.324229  0.419142  0.081938
# 2   0.658707  0.608447  0.216708  0.576256  0.950132
# 3   0.565700  0.547843  0.204832  0.814304  0.557763
# 4   0.923992  0.259894  0.730283  0.784338  0.204921
# ..       ...       ...       ...       ...       ...
# 95  0.972016  0.851255  0.799090  0.647673  0.319536
# 96  0.569663  0.144340  0.105282  0.458112  0.762606
# 97  0.541739  0.959142  0.205383  0.972936  0.442870
# 98  0.481718  0.268481  0.796819  0.461039  0.981058
# 99  0.167813  0.009306  0.640156  0.368833  0.023238
#
# [100 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(df.corr())
plt.show()

# %%
print('hello world 11')
# Out:
# hello world 11

# %%
82 - 1
# Out:
# 81

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.rand(100, 5))
df
# Out:
#            0         1         2         3         4
# 0   0.849210  0.837268  0.438118  0.319366  0.602842
# 1   0.773301  0.867203  0.174310  0.818101  0.129303
# 2   0.323926  0.623922  0.343059  0.298055  0.904832
# 3   0.624717  0.567961  0.800482  0.198774  0.150652
# 4   0.838740  0.062823  0.306542  0.334841  0.044693
# ..       ...       ...       ...       ...       ...
# 95  0.791351  0.928213  0.250322  0.824538  0.611748
# 96  0.861615  0.473862  0.505723  0.524240  0.836919
# 97  0.477275  0.540410  0.779727  0.034130  0.470341
# 98  0.995255  0.586210  0.318872  0.553013  0.742635
# 99  0.156597  0.717204  0.858299  0.735420  0.345824
#
# [100 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(df.corr())
plt.show()

# %%
print('hello world 12')
# Out:
# hello world 12

# %%
61 - 5
# Out:
# 56

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.rand(100, 5))
df
# Out:
#            0         1         2         3         4
# 0   0.225630  0.893507  0.875875  0.321805  0.119140
# 1   0.960166  0.631394  0.310750  0.774810  0.422517
# 2   0.882501  0.514536  0.350352  0.007216  0.104575
# 3   0.942877  0.810916  0.301652  0.261787  0.556456
# 4   0.933508  0.505994  0.231216  0.498450  0.842251
# ..       ...       ...       ...       ...       ...
# 95  0.046645  0.569136  0.900360  0.940752  0.750850
# 96  0.228414  0.016805  0.061043  0.507144  0.906830
# 97  0.612604  0.362344  0.238790  0.492878  0.872135
# 98  0.362798  0.689788  0.357067  0.384721  0.487038
# 99  0.677641  0.662508  0.126285  0.576798  0.395369
#
# [100 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(df.corr())
plt.show()

# %%
print('hello world 13')
# Out:
# hello world 13

# %%
70 - 57
# Out:
# 13

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.rand(100, 5))
df
# Out:
#            0         1         2         3         4
# 0   0.575640  0.101088  0.725198  0.934986  0.929353
# 1   0.748417  0.047868  0.879111  0.652054  0.098196
# 2   0.852948  0.499039  0.810243  0.393970  0.979112
# 3   0.506120  0.183620  0.152880  0.232162  0.426969
# 4   0.565434  0.439171  0.095245  0.263612  0.616452
# ..       ...       ...       ...       ...       ...
# 95  0.530537  0.605660  0.265116  0.867561  0.031080
# 96  0.381034  0.335793  0.621758  0.372894  0.796673
# 97  0.742640  0.177024  0.053773  0.585518  0.043486
# 98  0.657841  0.482995  0.720110  0.626630  0.266137
# 99  0.835834  0.772731  0.665557  0.201484  0.937936
#
# [100 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(df.corr())
plt.show()

# %%
print('hello world 14')
# Out:
# hello world 14

# %%
93 - 76
# Out:
# 17

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.rand(100, 5))
df
# Out:
#            0         1         2         3         4
# 0   0.062361  0.466572  0.276388  0.134838  0.289059
# 1   0.767828  0.971099  0.686129  0.805456  0.589159
# 2   0.566798  0.347168  0.537598  0.260441  0.807873
# 3   0.466016  0.045357  0.329527  0.789544  0.162128
# 4   0.036829  0.886455  0.414245  0.586949  0.913078
# ..       ...       ...       ...       ...       ...
# 95  0.247036  0.222467  0.497532  0.424256  0.989674
# 96  0.574331  0.881326  0.190976  0.752879  0.856429
# 97  0.529903  0.663277  0.891965  0.257178  0.853546
# 98  0.759075  0.765899  0.604502  0.252096  0.193737
# 99  0.785116  0.027454  0.836974  0.298956  0.669159
#
# [100 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(df.corr())
plt.show()

# %%
print('hello world 15')
# Out:
# hello world 15

# %%
6 - 35
# Out:
# -29

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.rand(100, 5))
df
# Out:
#            0         1         2         3         4
# 0   0.852858  0.842842  0.110350  0.955061  0.540839
# 1   0.625430  0.945367  0.403679  0.936978  0.141580
# 2   0.880820  0.044788  0.219460  0.299174  0.890383
# 3   0.002568  0.742127  0.507411  0.057174  0.549321
# 4   0.499736  0.173884  0.385022  0.580432  0.296309
# ..       ...       ...       ...       ...       ...
# 95  0.362292  0.175618  0.723272  0.186513  0.622257
# 96  0.718024  0.365546  0.510274  0.707938  0.021395
# 97  0.039042  0.937089  0.207825  0.622795  0.569687
# 98  0.328828  0.827836  0.150777  0.384449  0.122744
# 99  0.433704  0.494527  0.148482  0.473547  0.624052
#
# [100 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(df.corr())
plt.show()

# %%
print('hello world 16')
# Out:
# hello world 16

# %%
100 - 9
# Out:
# 91

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.rand(100, 5))
df
# Out:
#            0         1         2         3         4
# 0   0.112526  0.330282  0.603585  0.561841  0.335396
# 1   0.948918  0.351099  0.349001  0.262986  0.948172
# 2   0.750122  0.654900  0.375793  0.854405  0.199934
# 3   0.123451  0.460072  0.581988  0.989066  0.726353
# 4   0.428606  0.443508  0.251651  0.332781  0.006213
# ..       ...       ...       ...       ...       ...
# 95  0.746153  0.797986  0.771100  0.194110  0.857888
# 96  0.381080  0.677863  0.323606  0.689833  0.183611
# 97  0.021727  0.226277  0.474987  0.250558  0.022737
# 98  0.784735  0.441745  0.991733  0.487654  0.166411
# 99  0.349695  0.824232  0.523817  0.930256  0.219163
#
# [100 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(df.corr())
plt.show()

# %%
print('hello world 17')
# Out:
# hello world 17

# %%
74 - 40
# Out:
# 34

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.rand(100, 5))
df
# Out:
#            0         1         2         3         4
# 0   0.369485  0.014424  0.961712  0.311078  0.916816
# 1   0.896698  0.585295  0.992160  0.279449  0.857250
# 2   0.068553  0.879046  0.399690  0.942348  0.993706
# 3   0.994917  0.192417  0.392863  0.782007  0.314130
# 4   0.946437  0.153222  0.552035  0.505609  0.823433
# ..       ...       ...       ...       ...       ...
# 95  0.501686  0.243681  0.447690  0.687383  0.319300
# 96  0.286073  0.089336  0.989676  0.507993  0.550494
# 97  0.102175  0.937696  0.721025  0.774802  0.066092
# 98  0.348554  0.902554  0.084148  0.731129  0.046230
# 99  0.870252  0.474838  0.407953  0.777696  0.173436
#
# [100 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(df.corr())
plt.show()
