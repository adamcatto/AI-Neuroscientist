# %%
import matplotlib
matplotlib.use('Agg')

# %%
print('hello world 0')
# Out:
# hello world 0

# %%
71 - 79
# Out:
# -8

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.rand(100, 5))
df
# Out:
#            0         1         2         3         4
# 0   0.677162  0.236855  0.346308  0.080444  0.716551
# 1   0.729117  0.054417  0.290296  0.050031  0.267860
# 2   0.476124  0.328612  0.290702  0.159075  0.671199
# 3   0.474754  0.111454  0.669858  0.443526  0.875543
# 4   0.405041  0.341806  0.289887  0.556289  0.619625
# ..       ...       ...       ...       ...       ...
# 95  0.693422  0.008620  0.632303  0.296517  0.999955
# 96  0.137293  0.271954  0.083994  0.130633  0.051738
# 97  0.229247  0.478856  0.465886  0.394872  0.504459
# 98  0.987947  0.281388  0.044905  0.134842  0.474306
# 99  0.734958  0.177371  0.612656  0.920028  0.640678
#
# [100 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(df.corr())
plt.show()

# %%
print('hello world 1')
# Out:
# hello world 1

# %%
0 - 65
# Out:
# -65

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.rand(100, 5))
df
# Out:
#            0         1         2         3         4
# 0   0.101595  0.193704  0.067972  0.649037  0.720792
# 1   0.438156  0.590445  0.335298  0.287174  0.157843
# 2   0.180624  0.837397  0.226411  0.974091  0.493769
# 3   0.784495  0.026325  0.819399  0.686137  0.936025
# 4   0.105018  0.331384  0.641166  0.483868  0.851362
# ..       ...       ...       ...       ...       ...
# 95  0.528433  0.033214  0.379383  0.370791  0.032672
# 96  0.611289  0.857539  0.891908  0.069913  0.895059
# 97  0.908931  0.230997  0.703432  0.495998  0.697161
# 98  0.411548  0.513885  0.057958  0.973985  0.411064
# 99  0.057308  0.845114  0.172903  0.634101  0.780327
#
# [100 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(df.corr())
plt.show()

# %%
print('hello world 2')
# Out:
# hello world 2

# %%
84 - 51
# Out:
# 33

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.rand(100, 5))
df
# Out:
#            0         1         2         3         4
# 0   0.537309  0.842490  0.671254  0.368588  0.182985
# 1   0.659017  0.415326  0.953431  0.835951  0.748141
# 2   0.191605  0.887699  0.551371  0.127859  0.855962
# 3   0.235630  0.453332  0.092728  0.218745  0.701882
# 4   0.451188  0.482695  0.623530  0.841421  0.019325
# ..       ...       ...       ...       ...       ...
# 95  0.027999  0.857371  0.070375  0.731728  0.699531
# 96  0.614652  0.551097  0.944574  0.216221  0.383873
# 97  0.453107  0.307233  0.720873  0.297300  0.756010
# 98  0.882804  0.487781  0.002529  0.581920  0.779035
# 99  0.726829  0.032070  0.619296  0.708988  0.563210
#
# [100 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(df.corr())
plt.show()

# %%
print('hello world 3')
# Out:
# hello world 3

# %%
71 - 15
# Out:
# 56

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.rand(100, 5))
df
# Out:
#            0         1         2         3         4
# 0   0.760005  0.038770  0.698294  0.036468  0.605541
# 1   0.695354  0.952414  0.377925  0.062885  0.517905
# 2   0.908863  0.367479  0.389163  0.472916  0.857828
# 3   0.236664  0.430008  0.168913  0.423541  0.960054
# 4   0.534139  0.319186  0.316828  0.149947  0.168538
# ..       ...       ...       ...       ...       ...
# 95  0.720661  0.936388  0.252552  0.641104  0.407893
# 96  0.129806  0.127699  0.218266  0.951562  0.444634
# 97  0.089353  0.648405  0.837514  0.883782  0.872949
# 98  0.884424  0.909969  0.313251  0.618186  0.650345
# 99  0.832285  0.368574  0.640764  0.732492  0.164785
#
# [100 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(df.corr())
plt.show()

# %%
print('hello world 4')
# Out:
# hello world 4

# %%
88 - 35
# Out:
# 53

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.rand(100, 5))
df
# Out:
#            0         1         2         3         4
# 0   0.417622  0.710131  0.218303  0.393512  0.210494
# 1   0.945149  0.406512  0.050354  0.149970  0.700498
# 2   0.798911  0.728606  0.525530  0.616604  0.534626
# 3   0.796808  0.819527  0.227214  0.070348  0.071971
# 4   0.171052  0.784944  0.892422  0.330383  0.200084
# ..       ...       ...       ...       ...       ...
# 95  0.768207  0.584320  0.407900  0.550333  0.924969
# 96  0.777297  0.419015  0.408821  0.071765  0.302239
# 97  0.032812  0.730312  0.122734  0.830503  0.961474
# 98  0.962629  0.543107  0.461765  0.082364  0.727122
# 99  0.638436  0.063359  0.725024  0.804455  0.576363
#
# [100 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(df.corr())
plt.show()

# %%
print('hello world 5')
# Out:
# hello world 5

# %%
8 - 59
# Out:
# -51

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.rand(100, 5))
df
# Out:
#            0         1         2         3         4
# 0   0.875317  0.833168  0.948107  0.660228  0.923820
# 1   0.578189  0.621067  0.969677  0.526606  0.758149
# 2   0.411250  0.023505  0.021957  0.434832  0.285071
# 3   0.351375  0.483228  0.347860  0.354877  0.003229
# 4   0.523456  0.256154  0.294414  0.114807  0.295303
# ..       ...       ...       ...       ...       ...
# 95  0.696543  0.239395  0.940187  0.915073  0.578621
# 96  0.505460  0.657011  0.991433  0.075718  0.205794
# 97  0.922284  0.710095  0.043084  0.410787  0.136653
# 98  0.546849  0.648072  0.403686  0.133393  0.634075
# 99  0.594096  0.690457  0.326652  0.522276  0.588941
#
# [100 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(df.corr())
plt.show()

# %%
print('hello world 6')
# Out:
# hello world 6

# %%
5 - 17
# Out:
# -12

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.rand(100, 5))
df
# Out:
#            0         1         2         3         4
# 0   0.848002  0.958151  0.741312  0.430922  0.010093
# 1   0.285868  0.014130  0.419062  0.241694  0.564590
# 2   0.687756  0.410921  0.386030  0.695439  0.312217
# 3   0.812120  0.018706  0.748411  0.080324  0.805635
# 4   0.484642  0.079074  0.071954  0.994725  0.351750
# ..       ...       ...       ...       ...       ...
# 95  0.675199  0.773148  0.138333  0.683902  0.436334
# 96  0.375478  0.969696  0.474501  0.298058  0.096212
# 97  0.275146  0.503636  0.206054  0.467142  0.440108
# 98  0.260447  0.147028  0.089427  0.515863  0.850508
# 99  0.209351  0.672053  0.432223  0.370696  0.763039
#
# [100 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(df.corr())
plt.show()

# %%
print('hello world 7')
# Out:
# hello world 7

# %%
72 - 39
# Out:
# 33

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.rand(100, 5))
df
# Out:
#            0         1         2         3         4
# 0   0.458348  0.982323  0.145236  0.006356  0.936701
# 1   0.910734  0.721122  0.595188  0.742240  0.376980
# 2   0.670926  0.217525  0.384893  0.663450  0.229122
# 3   0.422827  0.573552  0.159417  0.624789  0.133203
# 4   0.342415  0.372069  0.348975  0.824578  0.387935
# ..       ...       ...       ...       ...       ...
# 95  0.364936  0.897718  0.263471  0.365365  0.330525
# 96  0.930722  0.366203  0.005032  0.826238  0.313621
# 97  0.488823  0.968193  0.822689  0.795363  0.203659
# 98  0.922973  0.077569  0.138448  0.489667  0.597799
# 99  0.480389  0.632510  0.778606  0.072348  0.845172
#
# [100 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(df.corr())
plt.show()

# %%
print('hello world 8')
# Out:
# hello world 8

# %%
75 - 58
# Out:
# 17

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.rand(100, 5))
df
# Out:
#            0         1         2         3         4
# 0   0.322772  0.654415  0.099317  0.010354  0.531485
# 1   0.503643  0.091568  0.596376  0.081928  0.083447
# 2   0.713243  0.823545  0.536089  0.227894  0.201577
# 3   0.764900  0.611865  0.139487  0.811199  0.257478
# 4   0.758740  0.344990  0.779453  0.554973  0.181388
# ..       ...       ...       ...       ...       ...
# 95  0.396509  0.960297  0.920247  0.831172  0.497597
# 96  0.305957  0.042878  0.080694  0.585304  0.402116
# 97  0.822471  0.715627  0.018590  0.479064  0.376343
# 98  0.196457  0.861269  0.713503  0.890582  0.197906
# 99  0.966840  0.266241  0.117702  0.109999  0.624780
#
# [100 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(df.corr())
plt.show()

# %%
print('hello world 9')
# Out:
# hello world 9

# %%
52 - 64
# Out:
# -12

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.rand(100, 5))
df
# Out:
#            0         1         2         3         4
# 0   0.263103  0.777973  0.670968  0.614354  0.962182
# 1   0.627385  0.940519  0.758189  0.162853  0.826489
# 2   0.357471  0.458174  0.604940  0.587063  0.514639
# 3   0.881393  0.874286  0.470911  0.344239  0.921060
# 4   0.179572  0.345282  0.738284  0.006903  0.798520
# ..       ...       ...       ...       ...       ...
# 95  0.263719  0.249572  0.019452  0.204997  0.378513
# 96  0.546790  0.683046  0.751026  0.991686  0.616942
# 97  0.860339  0.435172  0.334034  0.434215  0.141638
# 98  0.740169  0.072443  0.433205  0.914889  0.506512
# 99  0.544373  0.524364  0.012629  0.702776  0.449821
#
# [100 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(df.corr())
plt.show()

# %%
print('hello world 10')
# Out:
# hello world 10

# %%
98 - 62
# Out:
# 36

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.rand(100, 5))
df
# Out:
#            0         1         2         3         4
# 0   0.955299  0.959693  0.443365  0.749935  0.834614
# 1   0.708637  0.496289  0.660593  0.297551  0.996270
# 2   0.375234  0.630982  0.319152  0.125729  0.612648
# 3   0.217210  0.248090  0.501716  0.481301  0.242189
# 4   0.969196  0.648226  0.716289  0.965162  0.688886
# ..       ...       ...       ...       ...       ...
# 95  0.174692  0.829414  0.179607  0.212417  0.712838
# 96  0.119670  0.243845  0.913661  0.730082  0.072061
# 97  0.465525  0.612896  0.624372  0.812260  0.751456
# 98  0.460828  0.453476  0.854430  0.101941  0.659476
# 99  0.026607  0.053086  0.550747  0.592712  0.265857
#
# [100 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(df.corr())
plt.show()

# %%
print('hello world 11')
# Out:
# hello world 11

# %%
64 - 3
# Out:
# 61

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.rand(100, 5))
df
# Out:
#            0         1         2         3         4
# 0   0.221955  0.135992  0.009612  0.442220  0.749450
# 1   0.230454  0.736147  0.785917  0.246709  0.355170
# 2   0.904733  0.254806  0.752515  0.941469  0.327113
# 3   0.726556  0.849289  0.859069  0.453720  0.061692
# 4   0.528631  0.928255  0.879157  0.048783  0.259324
# ..       ...       ...       ...       ...       ...
# 95  0.229211  0.686693  0.272166  0.781008  0.689685
# 96  0.346906  0.137852  0.595350  0.374990  0.207834
# 97  0.544842  0.029199  0.085922  0.579777  0.522926
# 98  0.901072  0.425016  0.209419  0.435404  0.286457
# 99  0.779654  0.032336  0.309142  0.690060  0.529102
#
# [100 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(df.corr())
plt.show()

# %%
print('hello world 12')
# Out:
# hello world 12

# %%
90 - 37
# Out:
# 53

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.rand(100, 5))
df
# Out:
#            0         1         2         3         4
# 0   0.090501  0.913935  0.073291  0.609154  0.709749
# 1   0.497919  0.664431  0.081940  0.642207  0.672907
# 2   0.948036  0.432980  0.860719  0.811451  0.241563
# 3   0.150839  0.436979  0.241700  0.807589  0.871697
# 4   0.914932  0.811679  0.498216  0.508634  0.144627
# ..       ...       ...       ...       ...       ...
# 95  0.566585  0.689652  0.326426  0.785898  0.227737
# 96  0.766149  0.375298  0.894018  0.036078  0.058740
# 97  0.602879  0.361683  0.222519  0.508369  0.787662
# 98  0.172991  0.008426  0.921844  0.167970  0.992599
# 99  0.653599  0.543508  0.082393  0.685933  0.766947
#
# [100 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(df.corr())
plt.show()

# %%
print('hello world 13')
# Out:
# hello world 13

# %%
30 - 64
# Out:
# -34

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.rand(100, 5))
df
# Out:
#            0         1         2         3         4
# 0   0.234079  0.595155  0.699897  0.029205  0.456791
# 1   0.024744  0.663499  0.382863  0.807264  0.989126
# 2   0.722682  0.075746  0.325799  0.054447  0.579410
# 3   0.847322  0.012779  0.071135  0.235571  0.262376
# 4   0.898799  0.187305  0.047886  0.978961  0.467428
# ..       ...       ...       ...       ...       ...
# 95  0.351888  0.345853  0.427713  0.880560  0.393180
# 96  0.039206  0.046771  0.623434  0.316534  0.606337
# 97  0.985465  0.572308  0.833377  0.263536  0.436328
# 98  0.538254  0.276173  0.229913  0.472787  0.104534
# 99  0.849173  0.283361  0.835768  0.120820  0.910718
#
# [100 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(df.corr())
plt.show()

# %%
print('hello world 14')
# Out:
# hello world 14

# %%
15 - 3
# Out:
# 12

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.rand(100, 5))
df
# Out:
#            0         1         2         3         4
# 0   0.856524  0.677233  0.380943  0.257455  0.147637
# 1   0.165815  0.662031  0.012347  0.286602  0.011727
# 2   0.851349  0.016268  0.019715  0.642193  0.488518
# 3   0.002559  0.235182  0.083768  0.493743  0.608298
# 4   0.654817  0.569105  0.998397  0.503719  0.528758
# ..       ...       ...       ...       ...       ...
# 95  0.403667  0.959098  0.372417  0.783603  0.200269
# 96  0.717903  0.730220  0.110829  0.161176  0.300828
# 97  0.652472  0.466168  0.540882  0.321594  0.569866
# 98  0.341239  0.418561  0.182402  0.998947  0.639949
# 99  0.590762  0.148856  0.584100  0.399123  0.736371
#
# [100 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(df.corr())
plt.show()

# %%
print('hello world 15')
# Out:
# hello world 15

# %%
6 - 27
# Out:
# -21

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.rand(100, 5))
df
# Out:
#            0         1         2         3         4
# 0   0.795647  0.438085  0.253805  0.645512  0.410542
# 1   0.986759  0.808005  0.125676  0.767753  0.477315
# 2   0.720436  0.605256  0.746283  0.210746  0.831156
# 3   0.796618  0.789694  0.292862  0.825735  0.595013
# 4   0.361311  0.688010  0.272105  0.625609  0.783473
# ..       ...       ...       ...       ...       ...
# 95  0.833181  0.830311  0.109977  0.951019  0.457386
# 96  0.830684  0.872806  0.496162  0.666072  0.875081
# 97  0.676317  0.271880  0.791867  0.267083  0.704581
# 98  0.294552  0.356467  0.218551  0.115269  0.133694
# 99  0.191349  0.988160  0.369064  0.047026  0.092630
#
# [100 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(df.corr())
plt.show()

# %%
print('hello world 16')
# Out:
# hello world 16

# %%
50 - 60
# Out:
# -10

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.rand(100, 5))
df
# Out:
#            0         1         2         3         4
# 0   0.523633  0.453243  0.189259  0.320017  0.729518
# 1   0.432856  0.762301  0.132021  0.265821  0.873630
# 2   0.880434  0.436540  0.127963  0.203535  0.510309
# 3   0.632942  0.148690  0.458640  0.258734  0.769171
# 4   0.501799  0.805681  0.793377  0.294404  0.411833
# ..       ...       ...       ...       ...       ...
# 95  0.610795  0.907814  0.581557  0.807969  0.172630
# 96  0.686358  0.771054  0.235264  0.609602  0.820525
# 97  0.808543  0.075459  0.105012  0.126440  0.993215
# 98  0.165137  0.063222  0.824735  0.847385  0.974720
# 99  0.689111  0.526658  0.468239  0.806859  0.418003
#
# [100 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(df.corr())
plt.show()

# %%
print('hello world 17')
# Out:
# hello world 17

# %%
40 - 43
# Out:
# -3

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.rand(100, 5))
df
# Out:
#            0         1         2         3         4
# 0   0.412717  0.882776  0.838327  0.787344  0.605742
# 1   0.583208  0.446061  0.394907  0.824243  0.878255
# 2   0.870960  0.012174  0.760758  0.022539  0.385351
# 3   0.733540  0.560894  0.290539  0.376842  0.021175
# 4   0.953647  0.469695  0.384775  0.367246  0.952413
# ..       ...       ...       ...       ...       ...
# 95  0.715069  0.144273  0.814839  0.246348  0.328983
# 96  0.574803  0.157058  0.138185  0.069790  0.196664
# 97  0.267999  0.317680  0.852573  0.122853  0.625997
# 98  0.162507  0.860561  0.611307  0.430883  0.800540
# 99  0.069714  0.960344  0.041029  0.675175  0.870399
#
# [100 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(df.corr())
plt.show()

# %%
print('hello world 18')
# Out:
# hello world 18

# %%
9 - 44
# Out:
# -35

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.rand(100, 5))
df
# Out:
#            0         1         2         3         4
# 0   0.017088  0.558736  0.580125  0.010793  0.971304
# 1   0.838176  0.900699  0.057349  0.565843  0.406866
# 2   0.143034  0.634426  0.413671  0.544358  0.659848
# 3   0.688883  0.956699  0.735984  0.076037  0.111831
# 4   0.245647  0.642180  0.434576  0.361982  0.315268
# ..       ...       ...       ...       ...       ...
# 95  0.416053  0.665587  0.885481  0.565575  0.446739
# 96  0.607712  0.819014  0.378609  0.896796  0.028054
# 97  0.582092  0.644365  0.758228  0.892858  0.713959
# 98  0.844208  0.284147  0.848227  0.052588  0.143612
# 99  0.682560  0.434903  0.115746  0.966693  0.598260
#
# [100 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(df.corr())
plt.show()

# %%
print('hello world 19')
# Out:
# hello world 19

# %%
50 - 40
# Out:
# 10

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.rand(100, 5))
df
# Out:
#            0         1         2         3         4
# 0   0.332778  0.397055  0.919627  0.748154  0.907142
# 1   0.464876  0.174729  0.562421  0.134579  0.425061
# 2   0.721020  0.751973  0.912551  0.379441  0.188964
# 3   0.427745  0.853803  0.788106  0.692095  0.095459
# 4   0.714489  0.034295  0.230906  0.490203  0.379823
# ..       ...       ...       ...       ...       ...
# 95  0.775709  0.757596  0.396627  0.200771  0.340752
# 96  0.044594  0.678313  0.453895  0.336616  0.043219
# 97  0.452111  0.972376  0.216247  0.980103  0.540791
# 98  0.182719  0.713866  0.838458  0.588441  0.417764
# 99  0.626625  0.091782  0.874902  0.989614  0.033940
#
# [100 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(df.corr())
plt.show()
